# %%
import pandas as pd

# %%
df = pd.read_parquet('list_of_dates.parquet')

# %%
df1 = pd.read_parquet('total.parquet')

# %%
df2 = pd.read_parquet('goal_nutrition.parquet')

# %%
frames = [df,df1,df2]

# %%
df.shape
# Out:
# (587187, 1)

# %%
df1.shape
# Out:
# (587161, 6)

# %%
df2.shape
# Out:
# (587187, 6)

# %%
final_df = pd.concat(frames,axis=1)

# %%
df4 = pd.read_parquet('total_and_goal_nutrition.parquet')

# %%
df4
# Out:
#               Date  total_sugar  total_sodium  total_carbs  total_protein  \
# 0       2014-09-14        109.0        3658.0        340.0          186.0
# 1       2014-09-15         63.0         855.0         96.0           50.0
# 2       2014-09-16        100.0        2215.0        158.0          114.0
# 3       2014-09-17        105.0        1765.0        187.0           98.0
# 4       2014-09-18         71.0        1101.0        113.0          202.0
# ...            ...          ...           ...          ...            ...
# 587182  2015-03-02          NaN           NaN          NaN            NaN
# 587183  2015-03-03          NaN           NaN          NaN            NaN
# 587184  2015-03-04          NaN           NaN          NaN            NaN
# 587185  2015-03-14          NaN           NaN          NaN            NaN
# 587186  2015-03-15          NaN           NaN          NaN            NaN
#
#         total_fat  total_calories  goal_sugar  goal_sodium  goal_carbs  \
# ...

# %%
df5 = pd.read_parquet('total_and_goal_nutrition.parquet')

# %%
df5
# Out:
#               Date  total_sugar  total_sodium  total_carbs  total_protein  \
# 0       2014-09-14        109.0        3658.0        340.0          186.0
# 1       2014-09-15         63.0         855.0         96.0           50.0
# 2       2014-09-16        100.0        2215.0        158.0          114.0
# 3       2014-09-17        105.0        1765.0        187.0           98.0
# 4       2014-09-18         71.0        1101.0        113.0          202.0
# ...            ...          ...           ...          ...            ...
# 587182  2015-03-02          NaN           NaN          NaN            NaN
# 587183  2015-03-03          NaN           NaN          NaN            NaN
# 587184  2015-03-04          NaN           NaN          NaN            NaN
# 587185  2015-03-14          NaN           NaN          NaN            NaN
# 587186  2015-03-15          NaN           NaN          NaN            NaN
#
#         total_fat  total_calories  goal_sugar  goal_sodium  goal_carbs  \
# ...

# %%
df_filled = df5.fillna(0.0)

# %%
df_filled.head(1000)
# Out:
#            Date  total_sugar  total_sodium  total_carbs  total_protein  \
# 0    2014-09-14        109.0        3658.0        340.0          186.0
# 1    2014-09-15         63.0         855.0         96.0           50.0
# 2    2014-09-16        100.0        2215.0        158.0          114.0
# 3    2014-09-17        105.0        1765.0        187.0           98.0
# 4    2014-09-18         71.0        1101.0        113.0          202.0
# ..          ...          ...           ...          ...            ...
# 995  2015-01-20          8.0        2730.0          0.0           48.0
# 996  2015-01-22         19.0        2688.0        198.0          113.0
# 997  2015-01-23         12.0        2548.0         80.0           61.0
# 998  2015-01-26         23.0        1968.0        165.0           51.0
# 999  2015-01-27         28.0        1748.0        152.0           29.0
#
#      total_fat  total_calories  goal_sugar  goal_sodium  goal_carbs  \
# ...

# %%
df_filled.to_csv('total_and_goal_nutrition.csv', index=False)
