# %%
import pandas as pd

# %%
df = pd.read_parquet('food_name_nutration_value.parquet')

# %%
df
# Out:
#        Food_ID                              Food_Name  \
# 0        35027              French Vanilla Cappuccino
# 1        35028                       Peppermint Mocha
# 2        35029                    Pumpkin Spice Latte
# 3        35037                      Caramel Macchiato
# 4        35042                          Hot Chocolate
# ...        ...                                    ...
# 54666   118344                 Frozen Mocha, 24 fl oz
# 54667   153014  Sweet Black Pepper Bacon Wake Up Wrap
# 54668   174902                          Whiskey Smash
# 54669   131673                      Chicken Enchilada
# 54670   136001              Street Tacos, Carne Asada
#
#                                         Food_Description Food_Category  \
# 0      French Vanilla Cappuccino, Coffee, Drinks, Fla...     Beverages
# 1                      Peppermint Mocha, Coffee, 8 fl oz     Beverages
# 2                   Pumpkin Spice Latte, Coffee, 8 fl oz     Beverages
# ...

# %%
food_id_mapping = {}
counter = 1

# Iterate over the rows in the DataFrame
for index, row in df.iterrows():
    # Convert the Food_ID value to string
    food_id_str = str(row["Food_ID"])

    # Update the Food_ID value for the row
    if food_id_str.startswith("FNT"):
        new_food_id = f"FNT{str(counter).zfill(3)}"
        food_id_mapping[food_id_str] = new_food_id
        df.at[index, "Food_ID"] = new_food_id
        counter += 1

# Sort the DataFrame based on the index
df = df.sort_index()

# Print the mapping dictionary (optional)
print(food_id_mapping)
# Out:
# {}

# %%
df
# Out:
#        Food_ID                              Food_Name  \
# 0        35027              French Vanilla Cappuccino
# 1        35028                       Peppermint Mocha
# 2        35029                    Pumpkin Spice Latte
# 3        35037                      Caramel Macchiato
# 4        35042                          Hot Chocolate
# ...        ...                                    ...
# 54666   118344                 Frozen Mocha, 24 fl oz
# 54667   153014  Sweet Black Pepper Bacon Wake Up Wrap
# 54668   174902                          Whiskey Smash
# 54669   131673                      Chicken Enchilada
# 54670   136001              Street Tacos, Carne Asada
#
#                                         Food_Description Food_Category  \
# 0      French Vanilla Cappuccino, Coffee, Drinks, Fla...     Beverages
# 1                      Peppermint Mocha, Coffee, 8 fl oz     Beverages
# 2                   Pumpkin Spice Latte, Coffee, 8 fl oz     Beverages
# ...

# %%
df.to_parquet("updated_food_name_nutration_value.parquet", index=False)

# %%
df1 = pd.read_csv('food_name_nutration_value.csv')

# %%
df1.to_parquet('updated_food_name_nutration_value.parquet')

# %%
df1
# Out:
#         Food_ID                              Food_Name  \
# 0        FNT001              French Vanilla Cappuccino
# 1        FNT002                       Peppermint Mocha
# 2        FNT003                    Pumpkin Spice Latte
# 3        FNT004                      Caramel Macchiato
# 4        FNT005                          Hot Chocolate
# ...         ...                                    ...
# 54666  FNT54667                 Frozen Mocha, 24 fl oz
# 54667  FNT54668  Sweet Black Pepper Bacon Wake Up Wrap
# 54668  FNT54669                          Whiskey Smash
# 54669  FNT54670                      Chicken Enchilada
# 54670  FNT54671              Street Tacos, Carne Asada
#
#                                         Food_Description Food_Category  \
# 0      French Vanilla Cappuccino, Coffee, Drinks, Fla...     Beverages
# 1                      Peppermint Mocha, Coffee, 8 fl oz     Beverages
# 2                   Pumpkin Spice Latte, Coffee, 8 fl oz     Beverages
# ...

# %%
Food_ID.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-77bb725b2eeb> in <module>
# ----> 1 Food_ID.dtypes
#
# NameError: name 'Food_ID' is not defined
